# %% [markdown]
# # Assignment 3

# %%
# Tic-Tac-Toe  functions

from random import *

def print_board(board):
    for i in range (len(board)):
        print (board[i], end=' | ')
        if (i==2 or i == 5 or i==8):
            print ("\n")
            print("--------------")

def play_turns(start):
    current = start
    for i in range(9):
        if (current == 'player1'):
            print ("Player1 turn ----")
            move=int(input("Choose a place player1 : "))
            board[move-1]=player1
            current= 'player2'
        elif(current == 'player2'):
            print ("player2 turn ---")
            move=int(input("Choose a place player2 : "))
             #x = randint(0,8)
             #while (board[x] == 'X' or board[x] == '0'):
                 #x = randint(0,8)
            board[move-1] = player2
            current = 'player1'
             
        print ("Board State")
        print_board(board)

def check_winner(board):
    winner = False

    #check rows
    for i in range (0,len(board),3):
        if (board[i]==board[i+1] and board[i+1]==board[i+2]):
            print ("Winner is ", board[i])
            winner = True
    
    #check columns
    for i in range (0,3):
        if (board[i]==board[i+3] and board[i+3]==board[i+6]):
            print ("Winner is ", board[i])
            winner = True
    
    #check diagonal
    
    if (board[0] == board[4] and board[4] == board[8]):
        print ("Winner is ", board[0])
        winner = True
    
    if winner == False:
        print ("It's a tie")

# %%
# To play Tic-Tac-Toe we will use the following code
x = randint(0,1)

if x == 0:
    player1= 'X'
    player2= '0'
else:
    player2= 'X'
    player1= '0'

x = randint(0,1)

if x == 0:
    start='player1'
else:
    start='player2'


print ("Welcome to tic tac toe ")

print ("Player1 plays with ", player1)

print ("Player2 plays with ",player2)


print (start, " Starts")

board = [ i+1  for i in range(9) ]

#print board

print ("Begin Board State")

print_board(board)

play_turns(start)

#print board

print ("Final Board State")

print_board(board)

#check winner

check_winner(board)
# Out:
# Welcome to tic tac toe
# Player1 plays with  0
# Player2 plays with  X
# player1  Starts
# Begin Board State
# 1 | 2 | 3 |
#
# --------------
# 4 | 5 | 6 |
#
# --------------
# 7 | 8 | 9 |
#
# --------------
# Player1 turn ----
# Choose a place player1 : 1
# Board State
# 0 | 2 | 3 |
#
# --------------
# 4 | 5 | 6 |
#
# --------------
# 7 | 8 | 9 |
#
# --------------
# player2 turn ---
# Choose a place player2 : 2
# Board State
# 0 | X | 3 |
#
# --------------
# 4 | 5 | 6 |
#
# --------------
# 7 | 8 | 9 |
#
# --------------
# Player1 turn ----
# Choose a place player1 : 5
# Board State
# 0 | X | 3 |
#
# --------------
# 4 | 0 | 6 |
#
# --------------
# 7 | 8 | 9 |
#
# --------------
# player2 turn ---
# Choose a place player2 : 6
# Board State
# 0 | X | 3 |
#
# --------------
# 4 | 0 | X |
#
# --------------
# 7 | 8 | 9 |
#
# --------------
# Player1 turn ----
# Choose a place player1 : 9

# %% [markdown]
# # Question
#
# You have to define a class called TicTacToe using the logic used in the cells above.
# You can use the functions defined above or you can design your own functions.
# The objective is to instantiate one object when you decide to play the game.
# One object corresponds to 1 full game.
# This object would be used to play the turns and decide the winner.
# At the end, the object should print who the winner is or if it is a tie.

# %%
# Write your code here
from random import randint
game_continues = True

class TicTacToe:
    def __init__(self,champion):
        
        self.champion = champion
       
    def identity(self):
        global player1_name
        global player2_name
        player1_name = input("Enter player 1's name :- ")
        player2_name = input("Enter player 2's name :-" )
    def win(self):
      print(champion)
    def print_board(self):
      for i in range (len(board)):
         print(board[i],end=" | ")
         if (i==2 or i == 5 or i==8):
             print ("\n")
             print("--------------")

  
    def play_turns(self):
      current = start
      global game_continues 
      global player1_name
      global player2_name
      game_continues = True
      for i in range(9):
          while game_continues and not(board[0]==board[1]==board[2] or 
                                       board[3]==board[4]==board[5] or 
                                       board[6]==board[7]==board[8] or
                                       board[0]==board[3]==board[6] or
                                       board[1]==board[4]==board[7] or
                                       board[2]==board[5]==board[8] or
                                       board[0]==board[4]==board[8] or
                                       board[2]==board[4]==board[6]):
              if (current == player1_name) and game_continues:
                  print (player1_name," turn ----")
                  print (player1_name," plays with ", player1)
                  move=int(input("Choose a place : "))
                  board[move-1]=player1
                  current= player2_name
                  obj.print_board()
              elif(current == player2_name) and game_continues:
                  print (player2_name," turn ---")
                  print (player2_name, " plays with ",player2)
                  move=int(input("Choose a place : "))
          #x = randint(0,8)
          #while (board[x] == 'X' or board[x] == '0'):
           # x = randint(0,8)
                  board[move-1] = player2
                  current = player1_name
             
                  print ("Board State \n")
                  obj.print_board()

    def check_champion(self):
      winner = False
      global game_continues 
      game_continues =  True
      #rows    
      if (board[0]==board[1]==board[2]):
          game_continues = False
          print ("Champion is ", board[0])
          winner = True
      elif (board[0]==board[3]==board[6]):
          game_continues = False
          print ("Champion is ", board[0])
          winner = True
          
      elif  (board[3] == board[4] == board[5]):
          game_continues = False
          print("Champion is ", board[3])
          winner = True
      elif  (board[6] == board[7] == board[8]):
          game_continues = False
          print("Champion is ", board[6])
          winner = True
      elif  (board[1] == board[4] == board[7]):
          game_continues = False
          print("Champion is ", board[2])
          winner = True
                    
      elif  (board[2] == board[5] == board[8]):
          game_continues = False
          print("Champion is ", board[2])
          winner = True
      elif  (board[0] == board[4] == board[8]):
          game_continues = False
          print("Champion is ", board[2])
          winner = True
      elif  (board[2] == board[4] == board[6]):
          game_continues = False
          print("Champion is ", board[2])
          winner = True
          
      elif winner == False:
         print("It is a tie")
    
         
    


welcome=print("Welcome! Hope you enjoy playing Tic Tac Toe !!!!!!!\n\n")
champion="Final Board State\n\n"
obj=TicTacToe(champion)
obj.identity()
board=[i+1 for i in range(9)]
x = randint(0,1)

if x == 0:
    player1= 'X'
    player2= '0'
else:
    player2= 'X'
    player1= '0'

x=randint(0,1)

if x == 0:
    start = player1_name
else:
    start = player2_name
(obj.print_board())
obj.play_turns()
obj.win()
obj.print_board()
obj.check_champion()
# Out:
# Welcome! Hope you enjoy playing Tic Tac Toe !!!!!!!
#
#
# Enter player 1's name :- Manav
# Enter player 2's name :-Radhika
# 1 | 2 | 3 |
#
# --------------
# 4 | 5 | 6 |
#
# --------------
# 7 | 8 | 9 |
#
# --------------
# Radhika  turn ---
# Radhika  plays with  0
# Choose a place : 0
# Board State
#
# 1 | 2 | 3 |
#
# --------------
# 4 | 5 | 6 |
#
# --------------
# 7 | 8 | 0 |
#
# --------------
# Manav  turn ----
# Manav  plays with  X
# Choose a place : 2
# 1 | X | 3 |
#
# --------------
# 4 | 5 | 6 |
#
# --------------
# 7 | 8 | 0 |
#
# --------------
# Radhika  turn ---
# Radhika  plays with  0
# Choose a place : 1
# Board State
#
# 0 | X | 3 |
#
# --------------
# 4 | 5 | 6 |
#
# --------------
# 7 | 8 | 0 |
#
# --------------
# Manav  turn ----
# Manav  plays with  X
# Choose a place : 3
# 0 | X | X |
#
# --------------
# 4 | 5 | 6 |
#
# --------------
# 7 | 8 | 0 |
#
# --------------
# Radhika  turn ---
# Radhika  plays with  0
# Choose a place : 4
# Board State
#
# ...
